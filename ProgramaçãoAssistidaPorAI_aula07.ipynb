# %% [markdown]
# <a href="https://colab.research.google.com/github/Edykiran/Engenharia_de_Prompt_e_Aplicacao_AI/blob/main/Programa%C3%A7%C3%A3oAssistidaPorAI_aula07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula 07 _ Miniprojeto
#
# Nome: Henrique
# Disciplina: Engenharia de Prompt e Aplicações em IA
